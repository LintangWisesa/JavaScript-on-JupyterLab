// %%
function Person(name) {
    this.name = name;
}

var peter = new Person("Peter");

var util = require("util");
console.log(util.inspect(peter));
peter;
// Out:
// Person { name: 'Peter' }
// Person { name: 'Peter' }

// %%
Person.prototype.inspect = function inspect(depth) {
    return "Person named " + this.name;
};

peter;
// Out:
// Person named Peter

// %%
Person.prototype._toHtml = function _toHtml() {
    var style = (
        "display:inline-block;" +
        "padding:0.25em;" +
        "background:#ccc;" +
        "border: 1px solid #888;" +
        "border-radius:0.25em;" +
        "box-shadow: 0.8em 0.4em 0.4em black;"
    );
    return (
        "<div style='" + style + "'>" +
        this.inspect() +
        "</div>"
    );
};

peter;
// Out:
// Person named Peter

// %%
$$.html("<div style='background-color:lightblue;width:50px;height:50px'></div>");
// Out:
// <div style='background-color:lightblue;width:50px;height:50px'></div>

// %%
$$.png(require("fs").readFileSync("lintang.png").toString("base64"));
